# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
b=1.25
print(type(b))
# Out:
# <class 'float'>

# %%
c="kaviya"
print(type(c))
# Out:
# <class 'str'>

# %%
d='k'
print(type(d))
# Out:
# <class 'str'>

# %%
e=True
print(type(e))
# Out:
# <class 'bool'>

# %%
f={1,2,3,4}
print(type(f))
# Out:
# <class 'set'>

# %%
g=1,2
print(type(g))
# Out:
# <class 'tuple'>

# %%
h={1,2,3,4}
j={5,6,7,8}
o=h.union(j)
print(o)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
h={1,2,3,4}
j={3,4,7,8}
o=h.intersection(j)
print(o)
# Out:
# {3, 4}
