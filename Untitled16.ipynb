# %%
import pandas as pd
df = pd.read_csv(r"/content/chandra.csv")
df.head()
# Out:
#    Unnamed: 0 name of company                   college name       region  \
# 0           0            zeus  Pillai College of Engineering  Navi Mumbai
# 1           1    Aditya Birla  Pillai College of Engineering  Navi Mumbai
# 2           2       capgemini  Pillai College of Engineering  Navi Mumbai
# 3           3      CMClimited  Pillai College of Engineering  Navi Mumbai
# 4           4            emco  Pillai College of Engineering  Navi Mumbai
#
#    year
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018

# %%
x= df.year

# %%
x
# Out:
# 0       2018
# 1       2018
# 2       2018
# 3       2018
# 4       2018
#         ...
# 3093    2018
# 3094    2018
# 3095    2018
# 3096    2018
# 3097    2018
# Name: year, Length: 3098, dtype: int64

# %%
y= df['college name']

# %%
y
# Out:
# 0               Pillai College of Engineering
# 1               Pillai College of Engineering
# 2               Pillai College of Engineering
# 3               Pillai College of Engineering
# 4               Pillai College of Engineering
#                         ...
# 3093    Pune Institute of Computer Technology
# 3094    Pune Institute of Computer Technology
# 3095    Pune Institute of Computer Technology
# 3096    Pune Institute of Computer Technology
# 3097    Pune Institute of Computer Technology
# Name: college name, Length: 3098, dtype: object

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.plot(x, y)
plt.show()

# %%
plt.xlabel('year')
plt.ylabel('college name')
plt.title('statics')

plt.plot(x, y)
plt.show()

# %%
x1 = np.linspace(-np.pi, np.pi, 256)
x2 = np.linspace(-np.pi, np.pi, 256)

y1 = np.cos(x1)
y2 = np.sin(x2)

# %%
plt.plot(x1, y1, x2, y2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f3b20fd2610>,
#  <matplotlib.lines.Line2D at 0x7f3b1fd4a990>]
